# %%
def sum(arg):
    total = 0
    for val in arg:
        total += val
    return total

# %% [markdown]
# ![test1.png](attachment:test1.png)

# %% [markdown]
# ![test2.png](attachment:test2.png)

# %% [markdown]
# The results of the test show that the program expected the sum of the fractions from the data variable to equal 1, but they totaled 0.9, which resulted in the test failing.
